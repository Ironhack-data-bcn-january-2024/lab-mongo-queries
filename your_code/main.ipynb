# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# **⚠️ IMPORTANT: Limit your print to avoid infinite scrolling. Otherwise your
# code will be lost between print lines. If working with lists do:**
#
# ```python
# list(collection.find(query))[:5] #or a reasonably low number
# ```

# %%
import requests
import json
import pandas as pd
from getpass import getpass

# %% [markdown]
# Importing libraries and setting up connection

# %%
from pymongo import MongoClient
client = MongoClient("localhost:27017")

# %%
db = client["ironhack"]
c = db.get_collection("companies")

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
filt = {"name":"Babelgum"}
projection = {"_id":0, "name":1}

list(c.find(filt,projection))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
filt = {"number_of_employees":{"$gt":5000}}
list(c.find(filt).sort({"number_of_employees":-1}).limit(20))
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd67529941a'),
#   'name': 'Siemens',
#   'permalink': 'siemens',
#   'crunchbase_url': 'http://www.crunchbase.com/company/siemens',
#   'homepage_url': 'http://www.siemens.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'Siemens',
#   'category_code': 'hardware',
#   'number_of_employees': 405000,
#   'founded_year': 1847,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'automation, building-technologies, drive-technology, energy',
#   'alias_list': '',
#   'email_address': 'contact@siemens.com',
#   'phone_number': '49 89 636 34134',
#   'description': 'Electronics and Electrical Engineering',
#   'created_at': 'Thu Jul 31 09:29:43 UTC 2008',
#   'updated_at': 'Thu Nov 28 20:32:55 UTC 2013',
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
fil1 = {"founded_year":{"$gte":2000}}
fil2 = {"founded_year":{"$lte":2000}}

projection = {"_id":0, "name":1, "founded_year":1}

list(c.find({"$and":[fil1,fil2]},projection))[:5]
# Out:
# [{'name': 'AllofMP3', 'founded_year': 2000},
#  {'name': 'Steorn', 'founded_year': 2000},
#  {'name': 'MeeVee', 'founded_year': 2000},
#  {'name': 'PhotoBox', 'founded_year': 2000},
#  {'name': 'Boonex', 'founded_year': 2000}]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
filt1 = {"founded_year":{"$lte":2010}}
filt2 = {"ipo.valuation_amount":{"$gte": 100000000}}

projection = {"_id":0, "name":1, "ipo":1}

list(c.find({"$and":[filt1,filt2]},projection))[:5]
# Out:
# [{'name': 'Facebook',
#   'ipo': {'valuation_amount': 104000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 5,
#    'pub_day': 18,
#    'stock_symbol': 'NASDAQ:FB'}},
#  {'name': 'Twitter',
#   'ipo': {'valuation_amount': 18100000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2013,
#    'pub_month': 11,
#    'pub_day': 7,
#    'stock_symbol': 'NYSE:TWTR'}},
#  {'name': 'Yelp',
#   'ipo': {'valuation_amount': 1300000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2012,
#    'pub_month': 3,
#    'pub_day': 2,
#    'stock_symbol': 'NYSE:YELP'}},
#  {'name': 'LinkedIn',
#   'ipo': {'valuation_amount': 9310000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 2011,
#    'pub_month': 7,
#    'pub_day': 20,
#    'stock_symbol': 'NYSE:LNKD'}},
#  {'name': 'Amazon',
#   'ipo': {'valuation_amount': 100000000000,
#    'valuation_currency_code': 'USD',
#    'pub_year': 1997,
#    'pub_month': 5,
#    'pub_day': None,
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
filt1 = {"founded_year":{"$lte":2005}}
filt2 = {"number_of_employees":{"$lt":1000}}


list(c.find({"$and": [filt1, filt2]}).sort({"number_of_employees":-1}).limit(10))
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd675298933'),
#   'name': 'Infinera Corporation',
#   'permalink': 'infinera',
#   'crunchbase_url': 'http://www.crunchbase.com/company/infinera',
#   'homepage_url': 'http://www.infinera.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'InfineraCorp',
#   'category_code': 'network_hosting',
#   'number_of_employees': 974,
#   'founded_year': 2000,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': None,
#   'alias_list': 'Zepton Networks',
#   'email_address': '',
#   'phone_number': '408-572-5200',
#   'description': 'Optical Networking Systems',
#   'created_at': 'Tue Apr 29 19:43:09 UTC 2008',
#   'updated_at': 'Tue Jan 10 22:07:21 UTC 2012',
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
projection = {"_id":0, "name":1}

list(c.find({"partners":{"$exists": True}},projection))[0]
# Out:
# {'name': 'Wetpaint'}

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
projection = {"_id":0, "name":1}

list(c.find({"category_code":{"$type":10}},projection))[:5]
# Out:
# [{'name': 'Collective'},
#  {'name': 'Snimmer'},
#  {'name': 'KoolIM'},
#  {'name': 'Level9 Media'},
#  {'name': 'VidKing'}]

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
filt1 = {"number_of_employees":{"$gte":100}}
filt2 = {"number_of_employees":{"$lt":1000}}

projection = {"_id":0, "name":1, "number_of_employees":1}

list(c.find({"$and": [filt1, filt2]}, projection))[:5]
# Out:
# [{'name': 'AdventNet', 'number_of_employees': 600},
#  {'name': 'AddThis', 'number_of_employees': 120},
#  {'name': 'OpenX', 'number_of_employees': 305},
#  {'name': 'LifeLock', 'number_of_employees': 644},
#  {'name': 'Jajah', 'number_of_employees': 110}]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
list(c.find().sort({"ipo.valuation_amount":-1}))[:5]
# Out:
# [{'_id': ObjectId('52cdef7e4bab8bd67529a8b4'),
#   'name': 'GREE',
#   'permalink': 'gree',
#   'crunchbase_url': 'http://www.crunchbase.com/company/gree',
#   'homepage_url': 'http://www.gree-corp.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': 'gree_corp',
#   'category_code': 'games_video',
#   'number_of_employees': 700,
#   'founded_year': 2004,
#   'founded_month': 12,
#   'founded_day': 7,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'mobile-web, japan, tokyo, social-network, mobile-social-network, mobile-games',
#   'alias_list': None,
#   'email_address': 'inquiry@gree-corp.com',
#   'phone_number': '',
#   'description': 'Internet media business,SNS,  free game',
#   'created_at': 'Sat Dec 20 16:42:57 UTC 2008',
#   'updated_at': 'Tue Jan 01 21:37:04 UTC 2013',
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
projection = {"_id":0, "name":1, "number_of_employees":1}

list(c.find({}, projection).sort({"number_of_employees": -1}).limit(10))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'Toyota', 'number_of_employees': 320000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Nippon Telegraph and Telephone Corporation',
#   'number_of_employees': 227000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Tata Consultancy Services', 'number_of_employees': 200300},
#  {'name': 'Flextronics International', 'number_of_employees': 200000},
#  {'name': 'Safeway', 'number_of_employees': 186000}]

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
projection = {"_id":0, "name":1}

list(c.find({"founded_month":{"$gt":6}}, projection).limit(1000))[:5]
# Out:
# [{'name': 'Wetpaint'},
#  {'name': 'Zoho'},
#  {'name': 'Digg'},
#  {'name': 'Omnidrive'},
#  {'name': 'eBay'}]

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.000

# %%
filt1 = {"acquisition.price_amount":{"$gt":10000000}}
filt2 = {"founded_year": {"$lt":2000}}

projection = {"_id":0, "name":1, "acquisition.price_amount":1}

list(c.find({"$and":[filt1, filt2]}, projection))[:5]
# Out:
# [{'name': 'Postini', 'acquisition': {'price_amount': 625000000}},
#  {'name': 'SideStep', 'acquisition': {'price_amount': 180000000}},
#  {'name': 'Recipezaar', 'acquisition': {'price_amount': 25000000}},
#  {'name': 'PayPal', 'acquisition': {'price_amount': 1500000000}},
#  {'name': 'Snapfish', 'acquisition': {'price_amount': 300000000}}]

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
filt1 = {"acquisition.acquired_year":{"$gt":2010}}

projection = {"_id":0, "name":1, "acquisition":1}

list(c.find(filt1, projection).sort({"acquisition.price_amount":-1}))
# Out:
# [{'name': 'T-Mobile',
#   'acquisition': {'price_amount': 39000000000,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2011/03/20/in-the-race-for-more-spectrum-att-is-acquiring-t-mobile-for-39-billion/',
#    'source_description': 'In The Race For More Spectrum, AT&T Is Acquiring T-Mobile For $39 Billion',
#    'acquired_year': 2011,
#    'acquired_month': 3,
#    'acquired_day': 20,
#    'acquiring_company': {'name': 'AT&T', 'permalink': 'at-t'}}},
#  {'name': 'Goodrich Corporation',
#   'acquisition': {'price_amount': 18400000000,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://www.masshightech.com/stories/2011/09/19/daily37-UTC-shells-out-184-billion-for-Goodrich.html',
#    'source_description': 'UTC shells out $18.4 billion for Goodrich',
#    'acquired_year': 2011,
#    'acquired_month': 9,
#    'acquired_day': 22,
#    'acquiring_company': {'name': 'United Technologies',
# ...

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(c.find({},{"_id":0, "name":1, "founded_year":1}).sort({"founded_year":-1}))[:5]
# Out:
# [{'name': 'Fixya', 'founded_year': 2013},
#  {'name': 'Wamba', 'founded_year': 2013},
#  {'name': 'Advaliant', 'founded_year': 2013},
#  {'name': 'Fluc', 'founded_year': 2013},
#  {'name': 'iBazar', 'founded_year': 2013}]

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
list(c.find({"founded_day" : {"$lte":7}}).sort({"acquisition.price_amount":-1}).limit(10))
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd6752989a1'),
#   'name': 'Netscape',
#   'permalink': 'netscape',
#   'crunchbase_url': 'http://www.crunchbase.com/company/netscape',
#   'homepage_url': 'http://netscape.aol.com',
#   'blog_url': '',
#   'blog_feed_url': '',
#   'twitter_username': '',
#   'category_code': 'software',
#   'number_of_employees': None,
#   'founded_year': 1994,
#   'founded_month': 4,
#   'founded_day': 4,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': None,
#   'alias_list': '',
#   'email_address': '',
#   'phone_number': '',
#   'description': '',
#   'created_at': 'Tue May 06 00:27:28 UTC 2008',
#   'updated_at': 'Thu Nov 14 00:57:06 UTC 2013',
# ...

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
filt1 = {"number_of_employees":{"$gte":400}}
filt2 = {"category_code" :"web"} 

list(c.find({"$and":[filt1,filt2]}).sort({"number_of_employees":-1}))[:5]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd6752982a8'),
#   'name': 'Experian',
#   'permalink': 'experian',
#   'crunchbase_url': 'http://www.crunchbase.com/company/experian',
#   'homepage_url': 'http://www.experian.com',
#   'blog_url': 'http://www.experian.com/blogs/news/',
#   'blog_feed_url': '',
#   'twitter_username': 'ExperianMkt',
#   'category_code': 'web',
#   'number_of_employees': 15500,
#   'founded_year': 1980,
#   'founded_month': None,
#   'founded_day': None,
#   'deadpooled_year': None,
#   'deadpooled_month': None,
#   'deadpooled_day': None,
#   'deadpooled_url': None,
#   'tag_list': 'credit, creditreport',
#   'alias_list': '',
#   'email_address': '',
#   'phone_number': '(714) 830-7000',
#   'description': '',
#   'created_at': 'Tue Feb 12 23:03:11 UTC 2008',
#   'updated_at': 'Sat Dec 21 20:19:52 UTC 2013',
# ...

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
fil1 = {"acquisition.price_amount": {"$gt": 10000000}}
fil2 = {"acquisitions.price_currency_code": "EUR"}

proj = {"_id":0,"acquisitions.price_currency_code":1}

list(c.find({"$and":[fil1,fil2]},proj))


----------------- NIKO 

acc_10000 = {"acquisitions.price_amount": {"$gt":10000000}}
Euro = {"acquisitions.price_currency_code": "EUR"}
companies_between = {"$and": [acc_10000, Euro]}
projection = {"price_currency_code": 1, "_id": 0, "name": 1, "acquisitions.price_amount": 1}

results = list(c.find(companies_between, projection).limit(10))
results
# Out:
# []

# %%
fil1 = {"acquisition.price_amount": {"$gt": 10000000}}
fil2 = {"acquisitions.price_currency_code": "EUR"}

proj = {"_id":0,"acquisitions.price_currency_code":1, "name":1, "acquisition.price_amount":1}

list(c.find(fil2, proj))
# Out:
# [{'name': 'Yahoo!',
#   'acquisitions': [{'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'EUR'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
#    {'price_currency_code': 'USD'},
# ...

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
# Your Code

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
# Your Code

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
# Your Code

# %% [markdown]
# **⚠️ Did you do this?**
#
# ```python
# list(collection.find(query))[:5] #or a reasonably low number
# ```
